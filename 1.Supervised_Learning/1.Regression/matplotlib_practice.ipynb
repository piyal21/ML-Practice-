# %%
import matplotlib.pyplot as plt

x = [ 2023,2024,2025,2026]
y = [ 15,25,30,20]


plt.plot(x,y)
plt.show()

# %%
# using numpy array 

import numpy as np 

p = np.array([2020,2021,2022,2023,2024,2025])
q = np.array([10,13,17,19,26,3])


plt.plot(p,q)
plt.show()
